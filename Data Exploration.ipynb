# %%
import pandas as pd

# %%
ftxn = pd.read_csv('/Users/ayaz/Desktop/Defense Hackathon/anomaly-detection_anomaly-detection/ftxn2.txt', sep=",", header=None)
ftxn.columns = ["TXN_ID","TXTYPE","AMOUNT","FROMACCTID","TOACCTID","TXDATE","REFERENCE","ISFRAUD","ISFLAGGED"]
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (0,2,3,4) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
ftxn = ftxn.drop(ftxn.index[0])

# %%
ftxn
# Out:
#                TXN_ID    TXTYPE AMOUNT FROMACCTID TOACCTID  \
# 1        950060711303   PAYMENT    320     500607   800242
# 2        950060711401   PAYMENT     48     500607   800111
# 3        950060711402  TRANSFER   6209     500607   500929
# 4        950060711403   PAYMENT     66     500607   800252
# 5        950060711501   PAYMENT     47     500607   800116
# ...               ...       ...    ...        ...      ...
# 1533062  950134025802  TRANSFER   9159     501340   500730
# 1533063  950134025803   PAYMENT    323     501340   800201
# 1533064  950134025901   PAYMENT     75     501340   800136
# 1533065  950134025902  TRANSFER   3997     501340   501193
# 1533066  950134025903   PAYMENT    211     501340   800254
#
#                       TXDATE              REFERENCE ISFRAUD ISFLAGGED
# 1        2020-01-22T17:00:00      Dinner with Shane       N         Y
# 2        2020-01-23T08:00:00  Breakfast with Steven       N         Y
# ...

# %%
ftxn.nunique()
# Out:
# TXN_ID        1533066
# TXTYPE              2
# AMOUNT          19081
# FROMACCTID       1619
# TOACCTID         3215
# TXDATE           1098
# REFERENCE        2768
# ISFRAUD             1
# ISFLAGGED           1
# dtype: int64

# %%
faccount = pd.read_csv('/Users/ayaz/Desktop/Defense Hackathon/anomaly-detection_anomaly-detection/faccount.txt', sep=",", header=None)

faccount.columns = ["ACCTID","ACCTTYPE","ACCTNAME","FIRSTNAME","SURNAME","DOB","ACCTCREATED","ACCTRISK","ADDRESS","ADDRESS_LAT","ADDRESS_LON","CATEGORY"]

# %%
faccount = faccount.drop(faccount.index[0])

# %%
faccount
# Out:
#       ACCTID  ACCTTYPE              ACCTNAME  FIRSTNAME   SURNAME  \
# 1     800039  BUSINESS     Young Supermarket      Kevin     Young
# 2     800040  BUSINESS      Williams Grocery    Lindsay  Williams
# 3     800041    CREDIT     Myers Supermarket       Lisa     Myers
# 4     800042  BUSINESS  Martinez Supermarket   Brittany  Martinez
# 5     800043    CREDIT        Taylor Grocery      David    Taylor
# ...      ...       ...                   ...        ...       ...
# 1996  501232  BUSINESS       Richard, Morgan     Morgan   Richard
# 1997  501233    CREDIT       Roberts, Amanda     Amanda   Roberts
# 1998  501234   SAVINGS      Lopez, Christine  Christine     Lopez
# 1999  501235    CREDIT       Mullins, Robert     Robert   Mullins
# 2000  501236   SAVINGS         Collins, Mark       Mark   Collins
#
#                       DOB          ACCTCREATED ACCTRISK   ADDRESS  \
# 1     1982-02-23T00:00:00  2018-09-20T00:00:00   MEDIUM  BRISBANE
# ...

# %%
faccount.nunique()
# Out:
# ACCTID         2000
# ACCTTYPE          4
# ACCTNAME       1969
# FIRSTNAME       477
# SURNAME         685
# DOB            1853
# ACCTCREATED    1258
# ACCTRISK          3
# ADDRESS           1
# ADDRESS_LAT    1798
# ADDRESS_LON    1798
# CATEGORY         47
# dtype: int64

# %%
##### FOLDER "anomaly-detection-2"

# %%
ftxn2 = pd.read_csv('/Users/ayaz/Desktop/Defense Hackathon/anomaly-detection_anomaly-detection 2/ftxn2.txt', sep=",", header=None)
ftxn2.columns = ["TXN_ID","TXTYPE","AMOUNT","FROMACCTID","TOACCTID","TXDATE","REFERENCE","ISFRAUD","ISFLAGGED"]
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (0,2,3,4) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
ftxn2 = ftxn2.drop(ftxn2.index[0])

# %%
ftxn2
# Out:
#                TXN_ID    TXTYPE AMOUNT FROMACCTID TOACCTID  \
# 1        950060711303   PAYMENT    320     500607   800242
# 2        950060711401   PAYMENT     48     500607   800111
# 3        950060711402  TRANSFER   6209     500607   500929
# 4        950060711403   PAYMENT     66     500607   800252
# 5        950060711501   PAYMENT     47     500607   800116
# ...               ...       ...    ...        ...      ...
# 1533062  950134025802  TRANSFER   9159     501340   500730
# 1533063  950134025803   PAYMENT    323     501340   800201
# 1533064  950134025901   PAYMENT     75     501340   800136
# 1533065  950134025902  TRANSFER   3997     501340   501193
# 1533066  950134025903   PAYMENT    211     501340   800254
#
#                       TXDATE              REFERENCE ISFRAUD ISFLAGGED
# 1        2020-01-22T17:00:00      Dinner with Shane       N         Y
# 2        2020-01-23T08:00:00  Breakfast with Steven       N         Y
# ...

# %%
faccount = pd.read_csv('/Users/ayaz/Desktop/Defense Hackathon/anomaly-detection_anomaly-detection 2/faccount.txt', sep=",", header=None)

faccount.columns = ["ACCTID","ACCTTYPE","ACCTNAME","FIRSTNAME","SURNAME","DOB","ACCTCREATED","ACCTRISK","ADDRESS","ADDRESS_LAT","ADDRESS_LON","CATEGORY"]

# %%
faccount = faccount.drop(faccount.index[0])

# %%
faccount
# Out:
#       ACCTID  ACCTTYPE              ACCTNAME  FIRSTNAME   SURNAME  \
# 2     800040  BUSINESS      Williams Grocery    Lindsay  Williams
# 3     800041    CREDIT     Myers Supermarket       Lisa     Myers
# 4     800042  BUSINESS  Martinez Supermarket   Brittany  Martinez
# 5     800043    CREDIT        Taylor Grocery      David    Taylor
# 6     800044    CREDIT           Orr Grocery     Adrian       Orr
# ...      ...       ...                   ...        ...       ...
# 1996  501232  BUSINESS       Richard, Morgan     Morgan   Richard
# 1997  501233    CREDIT       Roberts, Amanda     Amanda   Roberts
# 1998  501234   SAVINGS      Lopez, Christine  Christine     Lopez
# 1999  501235    CREDIT       Mullins, Robert     Robert   Mullins
# 2000  501236   SAVINGS         Collins, Mark       Mark   Collins
#
#                       DOB          ACCTCREATED ACCTRISK   ADDRESS  \
# 2     1959-02-20T00:00:00  2018-02-24T00:00:00   MEDIUM  BRISBANE
# ...

# %%
faccount.nunique()
# Out:
# ACCTID         2000
# ACCTTYPE          4
# ACCTNAME       1969
# FIRSTNAME       477
# SURNAME         685
# DOB            1853
# ACCTCREATED    1258
# ACCTRISK          3
# ADDRESS           1
# ADDRESS_LAT    1798
# ADDRESS_LON    1798
# CATEGORY         47
# dtype: int64

# %%
faccount['ACCTRISK'].unique()
# Out:
# array(['MEDIUM', 'HIGH', 'LOW'], dtype=object)

# %% [markdown]
# ### USER AND CASE PROFILING

# %% [markdown]
# - Find the characteristics of users whose account is at risk
# - What are their background and where they spend their money.
# - Location

# %% [markdown]
# ### Restaurant Dataset

# %%
import pandas as pd

# %%
branches = pd.read_csv("/Users/ayaz/Desktop/Defense Hackathon/Restaurant/branches.csv")
dirty_data = pd.read_csv("/Users/ayaz/Desktop/Defense Hackathon/Restaurant/dirty_data.csv")
edges = pd.read_csv("/Users/ayaz/Desktop/Defense Hackathon/Restaurant/edges.csv")
missing_data = pd.read_csv("/Users/ayaz/Desktop/Defense Hackathon/Restaurant/missing_data.csv")
nodes = pd.read_csv("/Users/ayaz/Desktop/Defense Hackathon/Restaurant/nodes.csv")
outlier_data = pd.read_csv("/Users/ayaz/Desktop/Defense Hackathon/Restaurant/outlier_data.csv")

# %%
branches.head()
# Out:
#   branch_code branch_name  branch_lat  branch_lon
# 0          NS   Nickolson  -37.773803  144.983647
# 1          TP    Thompson  -37.861835  144.905716
# 2          BK      Bakers  -37.815834  145.046450

# %%
dirty_data.head()
# Out:
#     order_id        date      time order_type branch_code  \
# 0  ORDC01406  2018-08-07  15:16:03      Lunch          NS
# 1  ORDZ10125  2018-01-12  08:20:16  Breakfast          NS
# 2  ORDZ04175  2018-07-06  14:05:04      Lunch          NS
# 3  ORDI03691  2018-04-26  11:43:05     Dinner          NS
# 4  ORDZ04094  10-04-2018  11:12:40  Breakfast          NS
#
#                                          order_items  order_price  \
# 0                       [('Fries', 6), ('Salad', 4)]       140.80
# 1                    [('Cereal', 8), ('Pancake', 6)]       313.50
# 2  [('Steak', 3), ('Salad', 1), ('Chicken', 6), (...       714.00
# 3      [('Pancake', 9), ('Eggs', 10), ('Cereal', 2)]       480.25
# 4  [('Eggs', 5), ('Coffee', 3), ('Pancake', 9), (...       497.75
#
#    customer_lat  customer_lon  customerHasloyalty?  distance_to_customer_KM  \
# 0    -37.812539    144.954121                    1                    8.335
# ...

# %%
edges.head()
# Out:
#    Unnamed: 0          u          v  distance(m)  street type  speed(km/h)
# 0           0  711327755  711332946         58.0            1         15.0
# 1           2  711327755   55725841         15.0            2         20.0
# 2           3  711327755  711327760        165.0            1         15.0
# 3           4  711327756  703557073          4.0            0         10.0
# 4           5  711327756  711332946          8.0            1         15.0

# %%
missing_data.head()
# Out:
#     order_id        date      time order_type branch_code  \
# 0  ORDK01040  2018-04-13  11:22:49  Breakfast          BK
# 1  ORDX10726  2018-12-01  18:59:09     Dinner          BK
# 2  ORDX11076  2018-02-07  09:10:59  Breakfast         NaN
# 3  ORDZ08374  2018-10-31  17:58:18     Dinner          NS
# 4  ORDC05830  2018-02-19  09:31:16  Breakfast          NS
#
#                                     order_items  order_price  customer_lat  \
# 0  [('Pancake', 2), ('Cereal', 3), ('Eggs', 8)]       287.50    -37.814975
# 1                 [('Shrimp', 5), ('Pasta', 2)]       325.00    -37.799133
# 2               [('Pancake', 5), ('Coffee', 2)]       136.25    -37.805040
# 3               [('Shrimp', 10), ('Salmon', 3)]       663.00    -37.811983
# 4               [('Pancake', 6), ('Coffee', 8)]       205.50    -37.807231
#
#    customer_lon  customerHasloyalty?  distance_to_customer_KM  delivery_fee
# 0    144.950619                    0                   10.074     15.181547
# ...

# %%
nodes.head()
# Out:
#         node        lat         lon
# 0  711327755 -37.807675  144.955873
# 1  711327756 -37.807094  144.955978
# 2  711327759 -37.807301  144.957817
# 3  711327760 -37.807885  144.957719
# 4  777781264 -37.805221  144.952173

# %%
outlier_data.shape
# Out:
# (500, 12)

# %%
outlier_data.nunique()
# Out:
# order_id                   500
# date                       285
# time                        72
# order_type                   3
# branch_code                  3
# order_items                498
# order_price                457
# customer_lat               496
# customer_lon               496
# customerHasloyalty?          2
# distance_to_customer_KM    474
# delivery_fee               500
# dtype: int64

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')

plt.hist(outlier_data['order_price'])
# Out:
# (array([ 42.,  92., 100.,  77.,  52.,  53.,  33.,  31.,  16.,   4.]),
#  array([  44.5,  165.4,  286.3,  407.2,  528.1,  649. ,  769.9,  890.8,
#         1011.7, 1132.6, 1253.5]),
#  <a list of 10 Patch objects>)

# %%
Account_Number = []
Faker.seed(0)
for _ in range(501):
    Account_Number.append(fake.credit_card_number())

# %%
Account_Number
# Out:
# ['4604876475938242',
#  '5248924115781561',
#  '4387784080167',
#  '180009753513939',
#  '4871158714841859',
#  '3598947196593424',
#  '4947112201868487',
#  '3596947751591799',
#  '36304135256018',
#  '3530989101399167',
#  '2610903217300865',
#  '36131456208702',
#  '30563457923028',
#  '4419720769845645',
#  '2371508423759454',
#  '38924661093523',
#  '4696069602714277',
#  '6011890075470631',
#  '6512066503008913',
#  '4344217610471424',
#  '36512400034858',
#  '3509776582369406',
#  '2226515900422941',
#  '4241730428146546110',
#  '6011551717604520',
#  '3561113306016888',
#  '4936153492633',
#  '4087317643039213762',
#  '4197296687577389304',
#  '4550824926947118014',
#  '4075227586880917',
#  '180091634896766',
#  '30100248945174',
#  '4466602234500769',
#  '2709125609767012',
#  '340992518536716',
#  '4795194264183064',
#  '377510074089932',
#  '4886841269611610',
#  '2507660754151152',
#  '213120351923031',
#  '30510450932274',
#  '2234203557448523',
#  '30089426223589',
# ...

# %%
Phone_Number = []
Faker.seed(0)
for _ in range(501):
    Phone_Number.append(fake.phone_number())

# %%
Phone_Number
# Out:
# ['+1-604-876-4759x38242',
#  '001-948-924-1157',
#  '(565)938-7784x08016',
#  '+1-097-535-1393',
#  '(287)115-8714',
#  '(185)839-8947x19659',
#  '232.094.7112',
#  '+1-018-684-8339x69477',
#  '515.917.9533x04135',
#  '+1-560-123-0989x101',
#  '991.615.1090x3217',
#  '(008)691-4131',
#  '562.087.0916x34579',
#  '(302)258-4197',
#  '076.984.5642x80715',
#  '001-842-375-9459',
#  '001-924-661-0935x2337',
#  '960-696-0271x4278',
#  '001-890-075-4706x381',
#  '+1-206-650-3008x9131',
#  '344.217.6104x7142',
#  '512.400.0348x55909',
#  '765.823.6940x22455',
#  '+1-159-004-2294x568',
#  '173-042-8146',
#  '+1-461-187-7551x7176',
#  '5229611133',
#  '0168847793',
#  '534-926-3511x08731',
#  '(430)392-1376x5821',
#  '001-729-668-7577x38930',
#  '550-824-9269x471',
#  '+1-801-320-4075x227',
#  '001-868-809-1891x63489',
#  '769-930-0248x94517',
#  '+1-466-602-2345x00762',
#  '(912)560-9767x0172',
#  '9925185367',
#  '097-951-9426',
#  '+1-183-067-5375x100',
#  '(089)933-1886x8412',
# ...

# %%
df = pd.DataFrame(list(zip(Account_Number, Phone_Number)), 
               columns =['Account Number', 'Phone Number']) 
df
# Out:
#           Account Number           Phone Number
# 0       4604876475938242  +1-604-876-4759x38242
# 1       5248924115781561       001-948-924-1157
# 2          4387784080167    (565)938-7784x08016
# 3        180009753513939        +1-097-535-1393
# 4       4871158714841859          (287)115-8714
# ..                   ...                    ...
# 496     6011842456160489      262-305-7715x4924
# 497     3595740072103431             3844317187
# 498     2273846477996336       001-248-103-3582
# 499      213135243086680      534-380-6446x4100
# 500  4120502181101269408  001-923-808-2994x2297
#
# [501 rows x 2 columns]

# %%
df.to_csv("Account_Phone.csv")

# %%
Order_Number = []
from random import randint
for _ in range(500):
    value = randint(10000, 99999)
    order = "ORDX" + str(value)
    Order_Number.append(order)

# %%
Order_Number
# Out:
# ['ORDX30017',
#  'ORDX80884',
#  'ORDX57232',
#  'ORDX31357',
#  'ORDX41612',
#  'ORDX90026',
#  'ORDX98567',
#  'ORDX26913',
#  'ORDX73207',
#  'ORDX73331',
#  'ORDX91793',
#  'ORDX93750',
#  'ORDX94455',
#  'ORDX30439',
#  'ORDX64900',
#  'ORDX51169',
#  'ORDX83837',
#  'ORDX33643',
#  'ORDX93055',
#  'ORDX99912',
#  'ORDX53600',
#  'ORDX81274',
#  'ORDX66519',
#  'ORDX15373',
#  'ORDX42091',
#  'ORDX64236',
#  'ORDX99192',
#  'ORDX73032',
#  'ORDX68479',
#  'ORDX35149',
#  'ORDX15392',
#  'ORDX36577',
#  'ORDX40813',
#  'ORDX27089',
#  'ORDX96042',
#  'ORDX28893',
#  'ORDX26712',
#  'ORDX66875',
#  'ORDX79955',
#  'ORDX64436',
#  'ORDX91620',
#  'ORDX12746',
#  'ORDX76130',
#  'ORDX77088',
#  'ORDX32600',
#  'ORDX51479',
#  'ORDX54750',
#  'ORDX70123',
#  'ORDX15456',
#  'ORDX65969',
#  'ORDX33489',
#  'ORDX28040',
#  'ORDX21616',
#  'ORDX77329',
#  'ORDX99152',
#  'ORDX78903',
#  'ORDX21852',
#  'ORDX55174',
#  'ORDX26090',
#  'ORDX85597',
#  'ORDX86488',
#  'ORDX22561',
# ...

# %%
myset = set(Order_Number)
print(len(myset))
# Out:
# 498

# %%
len(Order_Number)
# Out:
# 500

# %%
Account_Number_new = []
Faker.seed(0)
for _ in range(501):
    Account_Number_new.append(fake.credit_card_number())

# %%
Phone_Number_new = []
Faker.seed(0)
for _ in range(501):
    Phone_Number_new.append(fake.phone_number())

# %%
df_new = pd.DataFrame(list(zip(Account_Number_new, Phone_Number_new, Order_Number)), 
               columns =['Account Number', 'Phone Number', 'Order Number']) 
df_new
# Out:
#        Account Number           Phone Number Order Number
# 0    4604876475938242  +1-604-876-4759x38242    ORDX30017
# 1    5248924115781561       001-948-924-1157    ORDX80884
# 2       4387784080167    (565)938-7784x08016    ORDX57232
# 3     180009753513939        +1-097-535-1393    ORDX31357
# 4    4871158714841859          (287)115-8714    ORDX41612
# ..                ...                    ...          ...
# 495    30488201072353      (339)304-1656x529    ORDX43778
# 496  6011842456160489      262-305-7715x4924    ORDX80999
# 497  3595740072103431             3844317187    ORDX11412
# 498  2273846477996336       001-248-103-3582    ORDX52322
# 499   213135243086680      534-380-6446x4100    ORDX82065
#
# [500 rows x 3 columns]

# %%
df_new.to_csv("Next5000.csv")

# %%
lat_lon = pd.read_csv("Cafes_and_restaurants__with_seating_capacity.csv")

# %%
lat_lon.head()
# Out:
#    Census year  Block ID  Property ID  Base property ID  \
# 0         2002       203       109358            109358
# 1         2002       204       101613            101613
# 2         2002       205       104469            104469
# 3         2002       206       103691            103691
# 4         2002       206       103691            103691
#
#                          Street address CLUE small area  \
# 0  832-834 Swanston Street CARLTON 3053         Carlton
# 1  377-391 Cardigan Street CARLTON 3053         Carlton
# 2   114-152 Grattan Street CARLTON 3053         Carlton
# 3   221-229 Faraday Street CARLTON 3053         Carlton
# 4   221-229 Faraday Street CARLTON 3053         Carlton
#
#                          Trading name  Industry (ANZSIC4) code  \
# 0                             Unibite                     4512
# 1                         Clyde Hotel                     4520
# 2  Royal Women's Hospital Coffee Shop                     4512
# ...

# %%
lat_lon['x coordinate'].nunique()
# Out:
# 1406

# %%
lat_lon['y coordinate'].nunique()
# Out:
# 1302

# %%
lat_lon.shape
# Out:
# (50652, 14)

# %%
df = lat_lon.groupby(['x coordinate', 'y coordinate']).size().reset_index(name='Freq')
print(df)
# Out:
#       x coordinate  y coordinate  Freq
# 0        144.90420     -37.82640    60
# 1        144.90429     -37.82536     4
# 2        144.90498     -37.82648     2
# 3        144.90500     -37.82650    15
# 4        144.90630     -37.82800    18
# ...            ...           ...   ...
# 2882     144.98870     -37.81480    12
# 2883     144.98871     -37.81482     1
# 2884     144.98960     -37.81660     1
# 2885     144.99050     -37.81060     5
# 2886     144.99056     -37.81058     1
#
# [2887 rows x 3 columns]

# %%
df_lat_lon = df[df['Freq']==1]

# %%
df_lat_lon.drop(columns=['Freq'])
# Out:
#       x coordinate  y coordinate
# 18       144.91651     -37.80087
# 19       144.91680     -37.80090
# 20       144.91683     -37.80088
# 27       144.91880     -37.79213
# 41       144.92545     -37.82167
# ...            ...           ...
# 2867     144.98731     -37.81635
# 2880     144.98825     -37.81639
# 2883     144.98871     -37.81482
# 2884     144.98960     -37.81660
# 2886     144.99056     -37.81058
#
# [506 rows x 2 columns]

# %%
df_lat_lon.to_csv("Lat_Lon.csv")

# %%
import pandas as pd
out = pd.read_csv("outlier_data-1.csv")

# %%
out.head()
# Out:
#     order_id     date      time order_type branch_code  \
# 0  ORDA07176   9/8/18  15:16:03      Lunch          BK
# 1  ORDI08901   8/2/18   9:10:59  Breakfast          NS
# 2  ORDI01822  22/1/18   8:40:33  Breakfast          NS
# 3  ORDY02007   2/1/18   8:00:00  Breakfast          TP
# 4  ORDY03043  17/4/18  11:22:49  Breakfast          TP
#
#                                          order_items  order_price  \
# 0                     [('Fries', 6), ('Chicken', 8)]        328.0
# 1                     [('Coffee', 4), ('Cereal', 9)]        219.0
# 2                       [('Coffee', 3), ('Eggs', 4)]        110.5
# 3  [('Eggs', 10), ('Coffee', 4), ('Cereal', 5), (...        597.5
# 4        [('Coffee', 8), ('Eggs', 4), ('Cereal', 1)]        169.0
#
#    customer_lat  customer_lon  customerHasloyalty?  distance_to_customer_KM  \
# 0    -37.800721    144.959719                    0                    8.245
# 1    -37.820800    144.979415                    0                    8.752
# ...

# %%
duplicated_lat_lon = out[out['customer_lat'].duplicated()]

# %%
duplicated_lat_lon['customer_lat'].value_counts()
# Out:
# -37.819805    5
# -37.816161    5
# -37.804061    5
# -37.819466    4
# -37.812413    4
#              ..
# -37.814920    1
# -37.812140    1
# -37.819881    1
# -37.811230    1
# -37.805700    1
# Name: customer_lat, Length: 68, dtype: int64
